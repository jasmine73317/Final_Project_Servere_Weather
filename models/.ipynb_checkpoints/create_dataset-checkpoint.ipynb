# %%
import pandas as pd

# %%
df = pd.read_csv("../Resources/finished_city_dfs/Albuquerque_df.csv")
df["City"] = "Albuquerque"
df2 = pd.read_csv("../Resources/finished_city_dfs/Atlanta_df.csv")
df2["City"] = "Atlanta"
df3 = pd.read_csv("../Resources/finished_city_dfs/Boston_df.csv")
df3["City"] = "Boston"
df4 = pd.read_csv("../Resources/finished_city_dfs/Charlotte_df.csv")
df4["City"] = "Charlotte"
df5 = pd.read_csv("../Resources/finished_city_dfs/Chicago_df.csv")
df5["City"] = "Chicago"
df6 = pd.read_csv("../Resources/finished_city_dfs/Dallas_df.csv")
df6["City"] = "Dallas"
df7 = pd.read_csv("../Resources/finished_city_dfs/Denver_df.csv")
df7["City"] = "Denver"
df8 = pd.read_csv("../Resources/finished_city_dfs/Detroit_df.csv")
df8["City"] = "Detroit"
df9 = pd.read_csv("../Resources/finished_city_dfs/Houston_df.csv")
df9["City"] = "Houston"
df10 = pd.read_csv("../Resources/finished_city_dfs/Indianapolis_df.csv")
df10["City"] = "Indianapolis"
df11 = pd.read_csv("../Resources/finished_city_dfs/Jacksonville_df.csv")
df11["City"] = "Jacksonville"
df12 = pd.read_csv("../Resources/finished_city_dfs/KansasCity_df.csv")
df12["City"] = "Kansas City"
df13 = pd.read_csv("../Resources/finished_city_dfs/LasVegas_df.csv")
df13["City"] = "Las Vegas"
df14 = pd.read_csv("../Resources/finished_city_dfs/LosAngeles_df.csv")
df14["City"] = "Los Angeles"
df15 = pd.read_csv("../Resources/finished_city_dfs/Miami_df.csv")
df15["City"] = "Miami"
df16 = pd.read_csv("../Resources/finished_city_dfs/Nashville_df.csv")
df16["City"] = "Nashville"
df17 = pd.read_csv("../Resources/finished_city_dfs/NewYork_df.csv")
df17["City"] = "New York"
df18 = pd.read_csv("../Resources/finished_city_dfs/Philadelphia_df.csv")
df18["City"] = "Philadelphia"
df19 = pd.read_csv("../Resources/finished_city_dfs/Phoenix_df.csv")
df19["City"] = "Phoenix"
df20 = pd.read_csv("../Resources/finished_city_dfs/Pittsburgh_df.csv")
df20["City"] = "Pittsburgh"
df21 = pd.read_csv("../Resources/finished_city_dfs/Portland_df.csv")
df21["City"] = "Portland"
df22 = pd.read_csv("../Resources/finished_city_dfs/SaintLouis_df.csv")
df22["City"] = "Saint Louis"
df23 = pd.read_csv("../Resources/finished_city_dfs/SanAntonio_df.csv")
df23["City"] = "San Antonio"
df24 = pd.read_csv("../Resources/finished_city_dfs/SanDiego_df.csv")
df24["City"] = "San Diego"
df25 = pd.read_csv("../Resources/finished_city_dfs/SanFrancisco_df.csv")
df25["City"] = "San Francisco"
df26 = pd.read_csv("../Resources/finished_city_dfs/Seattle_df.csv")
df26["City"] = "Seattle"

# %%
df = df.append(df2, ignore_index=True)
df = df.append(df3, ignore_index=True)
df = df.append(df4, ignore_index=True)
df = df.append(df5, ignore_index=True)
df = df.append(df6, ignore_index=True)
df = df.append(df7, ignore_index=True)
df = df.append(df8, ignore_index=True)
df = df.append(df9, ignore_index=True)
df = df.append(df10, ignore_index=True)
df = df.append(df11, ignore_index=True)
df = df.append(df12, ignore_index=True)
df = df.append(df13, ignore_index=True)
df = df.append(df14, ignore_index=True)
df = df.append(df15, ignore_index=True)
df = df.append(df16, ignore_index=True)
df = df.append(df17, ignore_index=True)
df = df.append(df18, ignore_index=True)
df = df.append(df19, ignore_index=True)
df = df.append(df20, ignore_index=True)
df = df.append(df21, ignore_index=True)
df = df.append(df22, ignore_index=True)
df = df.append(df23, ignore_index=True)
df = df.append(df24, ignore_index=True)
df = df.append(df25, ignore_index=True)
df = df.append(df26, ignore_index=True)

cities_df = pd.read_csv("../Resources/city_attributes.csv")

# %%
df = df.merge(cities_df, how="left", on="City")
df.head()
# Out:
#    Unnamed: 0        Date and Time  Temperature  Humidity  Wind_Speed  \
# 0           1  2012-10-01 13:00:00   285.120000      50.0         4.0
# 1           2  2012-10-01 14:00:00   285.154558      49.0         4.0
# 2           3  2012-10-01 15:00:00   285.233952      49.0         4.0
# 3           4  2012-10-01 16:00:00   285.313345      49.0         4.0
# 4           5  2012-10-01 17:00:00   285.392738      49.0         4.0
#
#    Wind_Direction  Pressure Weather_Description  Year  Month  ...  \
# 0           360.0    1024.0        sky is clear  2012     10  ...
# 1           360.0    1024.0        sky is clear  2012     10  ...
# 2           360.0    1024.0        sky is clear  2012     10  ...
# 3           360.0    1024.0        sky is clear  2012     10  ...
# 4           360.0    1024.0        sky is clear  2012     10  ...
#
#    Year Humidity Max  Year Humidity Min  Year Humidity Average  \
# 0              100.0                5.0              36.160968
# ...

# %%
df = df.loc[:,['Date and Time', 'Temperature', 'Humidity', 'Wind_Speed',
       'Wind_Direction', 'Pressure', 'Weather_Description', 'Year', 'Month',
       'Day', 'Hour', 'City', 'Latitude', 'Longitude']]
df.head()
# Out:
#          Date and Time  Temperature  Humidity  Wind_Speed  Wind_Direction  \
# 0  2012-10-01 13:00:00   285.120000      50.0         4.0           360.0
# 1  2012-10-01 14:00:00   285.154558      49.0         4.0           360.0
# 2  2012-10-01 15:00:00   285.233952      49.0         4.0           360.0
# 3  2012-10-01 16:00:00   285.313345      49.0         4.0           360.0
# 4  2012-10-01 17:00:00   285.392738      49.0         4.0           360.0
#
#    Pressure Weather_Description  Year  Month  Day  Hour         City  \
# 0    1024.0        sky is clear  2012     10    1    13  Albuquerque
# 1    1024.0        sky is clear  2012     10    1    14  Albuquerque
# 2    1024.0        sky is clear  2012     10    1    15  Albuquerque
# 3    1024.0        sky is clear  2012     10    1    16  Albuquerque
# 4    1024.0        sky is clear  2012     10    1    17  Albuquerque
#
#     Latitude   Longitude
# 0  35.084492 -106.651138
# 1  35.084492 -106.651138
# 2  35.084492 -106.651138
# ...

# %%
df.to_csv("classifier_dataset.csv", index=False)
